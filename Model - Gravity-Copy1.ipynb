# %%
import skmob
from skmob.models import Gravity
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
np.random.seed(0)

# %%
CSA_df = pd.read_csv('CSA_df.csv')
CSA_df.head()
# Out:
#   Airport        lat        lon           state state_code               city  \
# 0     ATL  33.640833 -84.427222         Georgia         GA            Atlanta
# 1     BOS  42.363611 -71.006111   Massachusetts         MA             Boston
# 2     CLT  35.219167 -80.935833  North Carolina         NC          Charlotte
# 3     CHI  41.881528 -87.829028        Illinois         IL            Chicago
# 4     DFW  32.894444 -97.029722           Texas         TX  Dallas/Fort Worth
#
#                                             CSA_Name
# 0  Atlanta--Athens-Clarke County--Sandy Springs, ...
# 1           Boston-Worcester-Providence, MA-RI-NH-CT
# 2                           Charlotte-Concord, NC-SC
# 3                       Chicago-Naperville, IL-IN-WI
# 4                           Dallas-Fort Worth, TX-OK

# %%
us_CSA = gpd.read_file('us_CSA.shp')
met = us_CSA[us_CSA['if_plot']==1]

# %%
met = met[['TotPop', 'CSA_Name', 'geometry']]
met = met.merge(right=CSA_df[['Airport', 'CSA_Name']], left_on='CSA_Name', right_on='CSA_Name')
met = met.rename(columns={'Airport': 'tile_ID', 'TotPop': 'population'}).sort_values(by='tile_ID')
tess = gpd.GeoDataFrame(met[['tile_ID', 'population']], geometry=met['geometry'], crs='EPSG:4326')
tess.head()
# Out:
#    tile_ID  population                                           geometry
# 0      ATL     6584708  POLYGON ((-85.16585 32.80850, -85.16563 32.808...
# 6      BOS     8200935  MULTIPOLYGON (((-71.88392 41.32650, -71.88213 ...
# 12     CHI     9907569  POLYGON ((-88.34208 41.11209, -88.34404 41.112...
# 16     CLT     2656704  POLYGON ((-81.42300 34.58677, -81.42269 34.587...
# 5      DEN     3466374  POLYGON ((-105.97241 38.89926, -105.97162 38.8...

# %%
OD = pd.read_csv('201904_OD_CSA.csv', index_col=0)
OD.head()
# Out:
#          ATL      BOS     CLT      DEN      DFW     DTW     HNL     IAH  \
# ATL      0.0  14164.0  2612.0  12058.0  12241.0  9195.0  1427.0  7834.0
# BOS  14116.0      0.0  7127.0   9950.0   8547.0  6668.0  1551.0  4643.0
# CLT   2673.0   7240.0     0.0   4937.0   5100.0  3464.0   294.0  3211.0
# DEN  11930.0   9963.0  4792.0      0.0  12312.0  7846.0  1980.0  9661.0
# DFW  12405.0   8695.0  5190.0  12330.0      0.0  7033.0  1654.0  3933.0
#
#          LAS      LAX  ...      PHL      PHX      SAN      SEA      SFO  \
# ATL  11396.0  15830.0  ...  11572.0   6964.0   4220.0   6052.0   7953.0
# BOS   7215.0  16494.0  ...  12129.0   6130.0   6138.0   6898.0  16984.0
# CLT   4747.0   3983.0  ...   5923.0   3155.0   1830.0   1746.0   3179.0
# DEN  15964.0  18762.0  ...   8293.0  19731.0  11205.0  12211.0  14066.0
# DFW  12232.0  17838.0  ...   8558.0   7940.0   5263.0   6984.0   8023.0
#
#         SLC      TPA      CHI      NYC      WAS
# ATL  4235.0  10660.0  22147.0  45042.0  28980.0
# BOS  3134.0   9766.0  21849.0  22648.0  31253.0
# CLT  1375.0   2959.0   6747.0  24802.0  11643.0
# DEN  8969.0   7126.0  22379.0  22049.0  19911.0
# DFW  4770.0   4706.0  18102.0  26112.0  13278.0
#
# [5 rows x 24 columns]

# %%
ODa = OD.stack().reset_index().set_axis(['origin', 'destination', 'flow'], axis=1)
ODa = ODa.sort_values(by=['origin', 'destination']).reset_index(drop=True)
fdf = skmob.FlowDataFrame(ODa, origin='origin', destination='destination', flow='flow', tessellation=tess,
                          tile_id='tile_ID')

# %%
tot_outflows = fdf[fdf['origin']!=fdf['destination']].groupby(by='origin', axis=0)[['flow']].sum()
tess = tess.merge(tot_outflows, left_on='tile_ID', right_on='origin').rename(columns={'flow': 'tot_outflow'})
tess.head()
# Out:
#   tile_ID  population                                           geometry  \
# 0     ATL     6584708  POLYGON ((-85.16585 32.80850, -85.16563 32.808...
# 1     BOS     8200935  MULTIPOLYGON (((-71.88392 41.32650, -71.88213 ...
# 2     CHI     9907569  POLYGON ((-88.34208 41.11209, -88.34404 41.112...
# 3     CLT     2656704  POLYGON ((-81.42300 34.58677, -81.42269 34.587...
# 4     DEN     3466374  POLYGON ((-105.97241 38.89926, -105.97162 38.8...
#
#    tot_outflow
# 0     285674.0
# 1     256955.0
# 2     412603.0
# 3     119230.0
# 4     279690.0

# %%
fdf_train = fdf[:403]
fdf_train.shape
# Out:
# (403, 3)

# %%
count = [1 if fdf_train.loc[i, 'origin']==fdf_train.loc[i, 'destination'] else 0 for i in fdf_train.index]
sum(count)
# Out:
# 17

# %%
count = [1 if fdf.loc[i, 'origin']==fdf.loc[i, 'destination'] else 0 for i in fdf.index]
sum(count)
# Out:
# 24

# %%
ODb = ODa.pivot(index='origin', columns='destination', values='flow')
ODb.head()
# Out:
# destination      ATL      BOS      CHI     CLT      DEN      DFW     DTW  \
# origin
# ATL              0.0  14164.0  22147.0  2612.0  12058.0  12241.0  9195.0
# BOS          14116.0      0.0  21849.0  7127.0   9950.0   8547.0  6668.0
# CHI          22189.0  22073.0      0.0  6918.0  22269.0  18006.0  6983.0
# CLT           2673.0   7240.0   6747.0     0.0   4937.0   5100.0  3464.0
# DEN          11930.0   9963.0  22379.0  4792.0      0.0  12312.0  7846.0
#
# destination     HNL      IAH      LAS  ...      MSP      NYC      PHL  \
# origin                                 ...
# ATL          1427.0   7834.0  11396.0  ...   6321.0  45042.0  11572.0
# BOS          1551.0   4643.0   7215.0  ...   6875.0  22648.0  12129.0
# CHI          2298.0  10813.0  20312.0  ...  16786.0  55294.0  13646.0
# CLT           294.0   3211.0   4747.0  ...   3084.0  24802.0   5923.0
# DEN          1980.0   9661.0  15964.0  ...  13724.0  22049.0   8293.0
#
# destination      PHX      SAN      SEA      SFO     SLC      TPA      WAS
# origin
# ATL           6964.0   4220.0   6052.0   7953.0  4235.0  10660.0  28980.0
# BOS           6130.0   6138.0   6898.0  16984.0  3134.0   9766.0  31253.0
# CHI          21368.0  11045.0  11580.0  18185.0  4533.0  15983.0  29763.0
# CLT           3155.0   1830.0   1746.0   3179.0  1375.0   2959.0  11643.0
# DEN          19731.0  11205.0  12211.0  14066.0  8969.0   7126.0  19911.0
#
# [5 rows x 24 columns]

# %%
plt.imshow(ODb, vmin=0, vmax=9e4)
plt.xlabel('Origin ID')
plt.ylabel('Destination ID')
plt.title('Real data (2019 Q4)', fontsize=11)
plt.colorbar().formatter.set_powerlimits((0, 0))

# %% [markdown]
# # Gravity model

# %% [markdown]
# ## Singly constrained

# %% [markdown]
# ### Power law deterrence function

# %%
singly_fitted1 = Gravity(gravity_type='singly constrained')
print(singly_fitted1)
# Out:
# Gravity(name="Gravity model", deterrence_func_type="power_law", deterrence_func_args=[-2.0], origin_exp=1.0, destination_exp=1.0, gravity_type="singly constrained")

# %%
singly_fitted1.fit(fdf_train, relevance_column='population')
print(singly_fitted1)
# Out:
# Gravity(name="Gravity model", deterrence_func_type="power_law", deterrence_func_args=[-0.02449164850510585], origin_exp=1.0, destination_exp=0.6825899779302953, gravity_type="singly constrained")

# %%
fdf_fit1 = singly_fitted1.generate(tess, tile_id_column='tile_ID', tot_outflows_column='tot_outflow',
                                   relevance_column='population', out_format='flows')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 12000.87it/s]
# E:\Program_Files\Anaconda\envs\skmob\lib\site-packages\skmob\models\gravity.py:43: RuntimeWarning: divide by zero encountered in power
#   return np.power(x, exponent)

# %%
fdf_fit1
# Out:
#     origin destination          flow
# 0      ATL         BOS  15411.016398
# 1      ATL         CHI  17731.800465
# 2      ATL         CLT   7391.689523
# 3      ATL         DEN   8507.005905
# 4      ATL         DFW  14787.196996
# ..     ...         ...           ...
# 547    WAS         SAN  10052.265781
# 548    WAS         SEA  12764.422827
# 549    WAS         SFO  20714.210472
# 550    WAS         SLC   8374.001422
# 551    WAS         TPA   9715.616267
#
# [552 rows x 3 columns]

# %%
OD_fit1 = pd.DataFrame(fdf_fit1[['origin', 'destination', 'flow']])
OD_rec1 = OD_fit1.pivot(index='origin', columns='destination', values='flow').fillna(0)
OD_rec1
# Out:
# destination           ATL           BOS           CHI           CLT  \
# origin
# ATL              0.000000  15411.016398  17731.800465   7391.689523
# BOS          12057.249571      0.000000  15965.077321   6530.678159
# CHI          19679.375650  22647.096918      0.000000  10587.286169
# CLT           5604.378830   6328.854058   7232.858002      0.000000
# DEN          12751.515379  14678.825622  16979.724742   6843.597899
# DFW          10184.354170  11614.905616  13437.623398   5447.513850
# DTW           7492.876925   8700.750248  10130.694740   4047.114918
# HNL           2946.539711   3414.536590   3900.797404   1584.454077
# IAH           6871.457934   7825.586372   9023.133890   3673.552062
# LAS          11409.669777  13163.414622  15141.642646   6127.223533
# LAX          18043.157343  20805.982751  23918.740003   9688.208653
# MCO          12761.487506  14457.982309  16499.952585   6842.896232
# MEM           1668.391785   1881.132898   2186.128959    888.256066
# MIA          15196.394079  17321.330562  19742.592443   8159.282462
# MSP           7766.872681   8978.835439  10504.414592   4176.449813
# NYC          30352.875719  36630.554932  40158.089095  16465.167258
# PHL           7627.055458   9047.028271  10069.656704   4145.042710
# PHX           9382.352638  10801.415362  12431.865105   5035.316064
# SAN           6682.754103   7704.449747   8854.678247   3588.090800
# SEA           9111.808146  10551.350550  12112.714799   4898.220405
# SFO          12743.092121  14718.901211  16904.987855   6845.638519
np.save('gravity.npy', OD_rec_long['flow'].to_numpy())

# %%
plt.imshow(OD_rec1, vmin=0, vmax=9e4)
plt.xlabel('Origin ID')
plt.ylabel('Destination ID')
plt.title('Singly constrained, power law', fontsize=11)
plt.colorbar().formatter.set_powerlimits((0, 0))

# %% [markdown]
# ### Exponential deterrence function

# %%
singly_fitted2 = Gravity(gravity_type='singly constrained', deterrence_func_type='exponential')
print(singly_fitted2)
# Out:
# Gravity(name="Gravity model", deterrence_func_type="exponential", deterrence_func_args=[-2.0], origin_exp=1.0, destination_exp=1.0, gravity_type="singly constrained")

# %%
singly_fitted2.fit(fdf, relevance_column='population')
print(singly_fitted2)
# Out:
# Gravity(name="Gravity model", deterrence_func_type="exponential", deterrence_func_args=[0.00011274633954644174], origin_exp=1.0, destination_exp=0.6149776849306317, gravity_type="singly constrained")

# %%
fdf_fit2 = singly_fitted2.generate(tess, tile_id_column='tile_ID', tot_outflows_column='tot_outflow',
                                   relevance_column='population', out_format='flows')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 23162.29it/s]

# %%
OD_fit2 = pd.DataFrame(fdf_fit2[['origin', 'destination', 'flow']])
OD_rec2 = OD_fit2.pivot(index='origin', columns='destination', values='flow').fillna(0)
OD_rec2.head()
# Out:
# destination           ATL           BOS           CHI           CLT  \
# origin
# ATL              0.000000  15604.064242  18645.951196   8860.702905
# BOS          13022.903768      0.000000  16950.379619   7746.247418
# CHI          21148.674046  23036.045510      0.000000  12083.395457
# CLT           6339.192412   6640.289616   7621.775410      0.000000
# DEN          12724.715447  13206.661752  17328.236850   7093.532737
#
# destination           DEN           DFW           DTW          HNL  \
# origin
# ATL           8739.566910  15508.718201  12693.967933  2101.810566
# BOS           7570.158785  12785.667147  12104.801174  1834.207534
# CHI          13498.788982  22406.210918  19792.715578  3246.835532
# CLT           3485.540783   6115.957119   5276.431586   835.041173
# DEN              0.000000  15438.699478  11351.892878  2553.534873
#
# destination           IAH          LAS  ...           MSP           NYC  \
# origin                                  ...
# ATL          14661.185876  5915.033345  ...   9927.677277  30043.714815
# BOS          11914.040429  5088.014985  ...   9144.425837  32023.870620
# CHI          20557.677647  9069.728464  ...  16028.015029  44068.268489
# CLT           5763.765813  2350.245708  ...   4040.655594  12780.954305
# DEN          13982.207108  7166.438865  ...  10176.948164  25254.853203
#
# destination           PHL           PHX           SAN           SEA  \
# origin
# ATL          15113.239565   9886.375126   7524.581402   8829.463567
# BOS          15448.088105   8321.127750   6360.254899   7990.571718
# CHI          21924.736062  14830.918841  11344.545717  13993.118462
# CLT           6432.292606   3910.232496   2977.511296   3547.691456
# DEN          12578.363737  11594.066725   8931.806396  10687.073912
#
# destination           SFO           SLC           TPA           WAS
# origin
# ATL          13844.635548   6648.109437   9301.781398  18530.436264
# BOS          11970.456565   5799.274388   7735.375328  18171.019492
# CHI          21310.659807  10316.920630  12196.834253  26746.266089
# CLT           5504.071956   2651.726433   3743.289096   7877.454347
# DEN          16818.209342   8113.454150   7472.951138  15373.894766
#
# [5 rows x 24 columns]

# %%
plt.imshow(OD_rec2, vmin=0, vmax=9e4)
plt.xlabel('Origin ID')
plt.ylabel('Destination ID')
plt.title('Singly constrained, exponential', fontsize=11)
plt.colorbar().formatter.set_powerlimits((0, 0))

# %% [markdown]
# ## Globally constrained gravity model

# %% [markdown]
# ### Power law deterrence function

# %%
globally_fitted1 = Gravity(gravity_type='globally constrained')
print(globally_fitted1)
# Out:
# Gravity(name="Gravity model", deterrence_func_type="power_law", deterrence_func_args=[-2.0], origin_exp=1.0, destination_exp=1.0, gravity_type="globally constrained")

# %%
globally_fitted1.fit(fdf, relevance_column='population')
print(globally_fitted1)
# Out:
# Gravity(name="Gravity model", deterrence_func_type="power_law", deterrence_func_args=[-0.05304299232341293], origin_exp=0.6250187103023493, destination_exp=0.6220923578385958, gravity_type="globally constrained")

# %%
fdf_fit3 = globally_fitted1.generate(tess, tile_id_column='tile_ID', tot_outflows_column='tot_outflow',
                                     relevance_column='population', out_format='flows')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 24047.61it/s]
# E:\Program_Files\Anaconda\envs\skmob\lib\site-packages\skmob\models\gravity.py:43: RuntimeWarning: divide by zero encountered in power
#   return np.power(x, exponent)

# %%
OD_fit3 = pd.DataFrame(fdf_fit3[['origin', 'destination', 'flow']])
OD_rec3 = OD_fit3.pivot(index='origin', columns='destination', values='flow').fillna(0)
OD_rec3.head()
# Out:
# destination           ATL           BOS           CHI          CLT  \
# origin
# ATL              0.000000  13431.018913  15479.268329  7181.010266
# BOS          13439.648818      0.000000  17398.881968  7747.996039
# CHI          15497.785766  17408.510204      0.000000  8804.626763
# CLT           7161.961777   7722.481586   8770.779188     0.000000
# DEN           7738.029446   8697.614911  10140.547357  4373.168583
#
# destination           DEN           DFW           DTW          HNL  \
# origin
# ATL           7752.572541  13032.276264  10515.934875  3298.684788
# BOS           8719.560509  14364.930047  12052.583823  3763.990601
# CHI          10171.759486  16762.974102  14260.649801  4273.823332
# CLT           4369.765499   7292.480054   6009.917912  1867.164007
# DEN              0.000000   8780.483409   6817.953284  2242.086103
#
# destination           IAH          LAS  ...           MSP           NYC  \
# origin                                  ...
# ATL          12299.096390  5696.806180  ...   8493.666203  25555.569428
# BOS          13515.317321  6438.315673  ...   9641.359671  31839.262103
# CHI          15656.627664  7419.939117  ...  11526.012240  33065.957331
# CLT           6874.409135  3215.319115  ...   4807.543747  14741.945768
# DEN           8149.532114  4032.588385  ...   5779.898516  16446.502622
#
# destination           PHL           PHX          SAN           SEA  \
# origin
# ATL          12595.390262   9269.230398  7350.141160   9070.209107
# BOS          15116.719113  10427.441718  8294.048032  10333.338586
# CHI          16222.753032  12032.333615  9540.830965  11857.206343
# CLT           7295.012640   5224.434533  4146.762833   5130.617053
# DEN           8052.261428   6537.454961  5142.723313   6323.554135
#
# destination           SFO          SLC          TPA           WAS
# origin
# ATL          14137.431839  6244.872012  7555.927480  15314.143662
# BOS          16017.887239  7061.497047  8191.784799  17861.795094
# CHI          18398.955433  8164.200149  9300.671740  19664.723503
# CLT           7985.180862  3525.217411  4236.907222   8912.598153
# DEN           9887.863265  4494.390803  4718.005599   9723.370238
#
# [5 rows x 24 columns]

# %%
plt.imshow(OD_rec3, vmin=0, vmax=9e4)
plt.xlabel('Origin ID')
plt.ylabel('Destination ID')
plt.title('Globally constrained, power law', fontsize=11)
plt.colorbar().formatter.set_powerlimits((0, 0))

# %% [markdown]
# ### Exponential deterrence function

# %%
globally_fitted2 = Gravity(gravity_type='globally constrained', deterrence_func_type='exponential')
print(globally_fitted2)
# Out:
# Gravity(name="Gravity model", deterrence_func_type="exponential", deterrence_func_args=[-2.0], origin_exp=1.0, destination_exp=1.0, gravity_type="globally constrained")

# %%
globally_fitted2.fit(fdf, relevance_column='population')
print(globally_fitted2)
# Out:
# Gravity(name="Gravity model", deterrence_func_type="exponential", deterrence_func_args=[9.776271562665538e-05], origin_exp=0.6166892474685293, destination_exp=0.6136791775766628, gravity_type="globally constrained")

# %%
fdf_fit4 = globally_fitted2.generate(tess, tile_id_column='tile_ID', tot_outflows_column='tot_outflow',
                                     relevance_column='population', out_format='flows')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 24018.92it/s]

# %%
OD_fit4 = pd.DataFrame(fdf_fit4[['origin', 'destination', 'flow']])
OD_rec4 = OD_fit4.pivot(index='origin', columns='destination', values='flow').fillna(0)
OD_rec4.head()
# Out:
# destination           ATL           BOS           CHI          CLT  \
# origin
# ATL              0.000000  14142.003486  16756.457861  7907.354986
# BOS          14151.350264      0.000000  18379.230384  8384.170973
# CHI          16777.076977  18389.692176      0.000000  9598.946767
# CLT           7885.780539   8355.773056   9560.992008     0.000000
# DEN           7967.112291   8374.664948  10761.075788  4462.083803
#
# destination           DEN           DFW           DTW          HNL  \
# origin
# ATL           7982.514713  13988.834346  11423.574845  2097.181456
# BOS           8396.400982  14096.794070  13060.291204  2220.233823
# CHI          10795.146933  17853.099591  15575.739121  2836.471638
# CLT           4458.512231   7737.312311   6613.444978  1167.459176
# DEN              0.000000   9535.665681   7095.708953  1699.110245
#
# destination           IAH          LAS  ...           MSP           NYC  \
# origin                                  ...
# ATL          13222.920930  5483.043792  ...   9004.702118  27087.436773
# BOS          13159.528033  5732.619681  ...   9990.080764  34107.649368
# CHI          16443.639363  7368.239390  ...  12654.067372  35027.199197
# CLT           7293.975231  3052.555806  ...   5118.831584  16000.093619
# DEN           8684.490346  4431.645264  ...   6296.243107  15946.090488
#
# destination           PHL           PHX          SAN           SEA  \
# origin
# ATL          13608.639288   9107.635715  6983.663834   8252.177954
# BOS          16523.980886   9344.290697  7191.601549   9016.161140
# CHI          17429.862805  12008.945714  9248.418162  11411.626520
# CLT           8041.582106   5050.350443  3874.159050   4638.960354
# DEN           7942.388224   7156.185499  5545.219043   6664.171953
#
# destination           SFO          SLC          TPA           WAS
# origin
# ATL          12905.582408  6135.849115  8335.245457  16633.143511
# BOS          13553.442068  6493.544408  8462.998609  19482.561798
# CHI          17401.026321  8331.793364  9779.923484  21210.289129
# CLT           7188.416805  3427.429435  4691.982526   9818.850910
# DEN          10454.898149  4990.674285  4717.945776   9681.090193
#
# [5 rows x 24 columns]

# %%
plt.imshow(OD_rec4, vmin=0, vmax=9e4)
plt.xlabel('Origin ID')
plt.ylabel('Destination ID')
plt.title('Globally constrained, exponential', fontsize=11)
plt.colorbar().formatter.set_powerlimits((0, 0))
